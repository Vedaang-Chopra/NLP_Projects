# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os
import platform
import sys

# %%
#  Setting Path to Dataset
def check_if_colab():
    if 'google.colab' in sys.modules:
        return True
    return False

# %%
if check_if_colab():
    print("Running on Google Colab")
    # from google.colab import drive
    # drive.mount('/content/drive')
    # BASE_PATH_TO_DATASETS='/content/drive/MyDrive/OMSCS/cs7641/All assignments/Assignments/Assignment-1'
    # BASE_PATH_TO_DATASETS=os.path.join(BASE_PATH_TO_DATASETS,'pubg')
else:
  if platform.system().lower().__contains__('windows'):
      BASE_PATH_TO_PROJECT_REPOSITORY=(os.sep).join(os.getcwd().split(os.sep)[:os.getcwd().split(os.sep).index('Parsec_Assignment')+1])
      BASE_PATH_TO_DATASETS=os.path.join(BASE_PATH_TO_PROJECT_REPOSITORY,'dataset')
      BASE_PATH_TO_CODE_BASE =os.path.join(BASE_PATH_TO_DATASETS, 'code_base')

  elif platform.system().lower().__contains__('linux'):
      BASE_PATH_TO_PROJECT_REPOSITORY=(os.sep).join(os.getcwd().split(os.sep)[:os.getcwd().split(os.sep).index('Parsec_Assignment')+1])
      BASE_PATH_TO_DATASETS=os.path.join(BASE_PATH_TO_PROJECT_REPOSITORY,'dataset')
      BASE_PATH_TO_CODE_BASE=os.path.join(BASE_PATH_TO_PROJECT_REPOSITORY, 'code_base')
  else:
      print('OS Error')
os.listdir(BASE_PATH_TO_DATASETS)
# Out:
# ['DataSet.xlsx',
#  'modified_dataset.xlsx',
#  'modified_dataset_v1.xlsx',
#  'modified_dataset_v2.xlsx',
#  'modified_dataset_v3.xlsx',
#  'modified_testing_df.csv',
#  'modified_training_df.csv']

# %% [markdown]
# #### Loading Dataset

# %%
training_data = pd.read_csv(os.path.join(BASE_PATH_TO_DATASETS, 'modified_training_df.csv'))
testing_data = pd.read_csv(os.path.join(BASE_PATH_TO_DATASETS, 'modified_testing_df.csv'))

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(training_data['pdf_text_sample_cleaned'], training_data['target_col'], 
                                                    test_size=0.1,
                                                    random_state=42,
                                                    stratify=training_data['target_col']
                                                    )

# %%
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((1255,), (140,), (1255,), (140,))

# %% [markdown]
# ### Basic Bag of Words Implementation

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_features=1000, ngram_range=(1, 3))

# %%
X_train_vectorized = tfidf.fit_transform(X_train)
X_val_vectorized = tfidf.transform(X_val)

# %%
(tfidf.get_feature_names_out())
# Out:
# array(['aa', 'accessory', 'accordance', 'according', 'accuracy',
#        'accurate', 'accurate reliable', 'accurate reliable however',
#        'acoustic', 'actual', 'acuity', 'acuity lighting',
#        'acuity lighting reserved', 'addition', 'additional',
#        'additional information', 'adjustable', 'agency', 'agency agency',
#        'agency agency agency', 'agency agency file', 'agency file',
#        'agency file number', 'air', 'alloy', 'alpha', 'also', 'aluminum',
#        'ambient', 'ambient temperature', 'amperage', 'ampere',
#        'ampere range', 'ampere rating', 'ampere rating opening', 'angle',
#        'angle hex', 'appearance', 'applicable',
#        'applicable documentation', 'applicable specification',
#        'applicable specification sheet', 'application', 'applied',
#        'appropriate', 'approval', 'area', 'area element',
#        'area element area', 'arm', 'assembly', 'attach', 'attenuation',
#        'attenuation frequency', 'attenuation power', 'automotive',
#        'availability', 'available', 'available reference',
#        'available reference full', 'avenue', 'average', 'average rate',
#        'average time', 'average time current', 'axial', 'axial lead',
#        'axial lead cartridge', 'ballast', 'base', 'based', 'battery',
#        'battery emergency', 'beam', 'bel', 'bel fuse', 'bel fuse rev',
#        'bend', 'bend radius', 'bending', 'best', 'black', 'black reel',
#        'blade', 'block', 'blow', 'blue', 'board', 'body', 'bottom', 'box',
#        'braid', 'braid tinned', 'breaking', 'breaking capacity', 'bridge',
#        'brightness', 'bronze', 'bulk', 'bulk na', 'bulk na na', 'burner',
#        'buy', 'ca', 'cable', 'cable shall', 'calculated', 'call', 'came',
#        'came available', 'came available reference', 'cap', 'capability',
#        'capacitance', 'capacitance unbalance', 'capacity', 'card',
#        'cartridge', 'cartridge fuse', 'case', 'category', 'cause', 'ce',
#        'ceiling', 'center', 'ceramic', 'certificate', 'certified',
#        'chamber', 'change', 'change without', 'change without notice',
#        'characteristic', 'characteristic impedance', 'charging', 'chart',
#        'chip', 'circuit', 'circuit board', 'circuit protection', 'clamp',
#        'class', 'cleaning', 'clear', 'clip', 'clock', 'coax', 'coaxial',
#        'code', 'cold', 'cold resistance', 'cold resistance nominal',
#        'color', 'color code', 'colors', 'commercial', 'compatible',
#        'complete', 'complete disclaimer', 'complete disclaimer notice',
#        'compliance', 'compliance directive', 'compliant', 'component',
#        'concentricity', 'condition', 'conductor', 'conductor outer',
#        'conductor shield', 'configuration', 'connected', 'connection',
#        'connectivity', 'connectivity family',
#        'connectivity family reserved', 'connector', 'considered',
#        'constant', 'construction', 'consult', 'consult factory',
#        'contact', 'contact material', 'content', 'contents', 'continuous',
#        'continuous operation', 'control', 'cooling', 'copper',
#        'copper alloy', 'copy', 'copy document',
#        'copy document uncontrolled', 'copy te', 'copy te connectivity',
#        'cord', 'cover', 'coverage', 'covered', 'crimp', 'crimp female',
#        'crimp male', 'crimp male right', 'crimp male straight',
#        'crimp tool', 'current', 'current rated', 'current rated voltage',
#        'current rating', 'current time', 'curve', 'custom', 'customer',
#        'cut', 'cutting', 'damage', 'damages', 'data', 'data sheet',
#        'date', 'date publication', 'defined', 'delay', 'derivation',
#        'derivation preceding', 'derivation preceding test', 'derived',
#        'description', 'design', 'designed', 'designed may',
#        'designed may used', 'detail', 'detailed', 'determined',
#        'determined following', 'device', 'diagram', 'diameter',
#        'dielectric', 'different', 'digital', 'dim', 'dimension', 'din',
#        'direct', 'direction', 'directive', 'disclaimer',
#        'disclaimer notice', 'dissipation', 'distance', 'distribution',
#        'distribution center', 'document', 'document subject',
#        'document uncontrolled', 'document uncontrolled copy',
#        'documentation', 'documentation shall', 'drawing', 'drive',
#        'driver', 'drop', 'dual', 'due', 'dwell', 'dwell time', 'easy',
#        'edge', 'effectiveness', 'either', 'electrical',
#        'electrical series', 'electrical table', 'electronic',
#        'electronics', 'element', 'element area', 'element area element',
#        'elongation', 'emergency', 'en', 'end', 'end cable', 'energy',
#        'ensure', 'entry', 'environment', 'environmental', 'equipment',
#        'equivalent', 'eu', 'evaluate', 'evaluate suitability',
#        'evaluate suitability test', 'even', 'example', 'exceed',
#        'expressly', 'expressly set', 'expressly set forth', 'facility',
#        'factor', 'factory', 'failure', 'family', 'family reserved',
#        'fast', 'feed', 'female', 'female straight', 'field', 'figure',
#        'file', 'file number', 'final', 'finger', 'finger crimp',
#        'finger crimp male', 'finish', 'finished', 'finished cable',
#        'finished cable shall', 'fixture', 'flame', 'flammability',
#        'flange', 'flat', 'flexible', 'flux', 'following',
#        'following formula', 'foot', 'force', 'form', 'formula', 'forth',
#        'forth applicable', 'forth applicable documentation', 'free',
#        'frequency', 'frequency attenuation', 'full', 'full order',
#        'function', 'furnished', 'furnished accurate',
#        'furnished accurate reliable', 'fuse', 'fuse clip', 'fuse rev',
#        'fuse subject', 'fuse subject change', 'gauge', 'general',
#        'generator', 'glass', 'gold', 'greater', 'green', 'ground',
#        'group', 'guide', 'halogen', 'halogen free', 'handling',
#        'hardware', 'heat', 'heat method', 'heating', 'height', 'herein',
#        'hex', 'hex solder', 'hex solder crimp', 'high', 'higher',
#        'holder', 'hole', 'horizontal', 'housing', 'however',
#        'however independently', 'however independently evaluate',
#        'humidity', 'ideal', 'identification', 'impedance', 'important',
#        'important incorporated', 'important incorporated came', 'inch',
#        'included', 'incorporated', 'incorporated came',
#        'incorporated came available', 'independently',
#        'independently evaluate', 'independently evaluate suitability',
#        'individual', 'indoor', 'inductance', 'industrial', 'industry',
#        'information', 'information furnished',
#        'information furnished accurate', 'information herein',
#        'information provided', 'information subject', 'initial', 'inner',
#        'inner conductor', 'input', 'input current', 'inspection',
#        'installation', 'insulation', 'insulation resistance', 'insulator',
#        'integral', 'intended', 'interface', 'internal', 'international',
#        'interrupting', 'interrupting rating',
#        'interrupting rating nominal', 'inverter', 'iron', 'iso', 'issue',
#        'issue note', 'issue note printed', 'issue page',
#        'issue page note', 'item', 'jack', 'jacket', 'jacket color',
#        'junction', 'key', 'kit', 'knowledge', 'knurl', 'knurl solder',
#        'knurl solder crimp', 'laboratory', 'lamp', 'latest', 'layout',
#        'lead', 'lead cartridge', 'least', 'led', 'left', 'length',
#        'length width', 'lens', 'less', 'level', 'level ambient',
#        'level ambient temperature', 'liable', 'liable damages', 'life',
#        'light', 'lighting', 'lighting reserved', 'limited', 'line',
#        'linear', 'list', 'listed', 'load', 'location', 'long', 'loss',
#        'low', 'low loss', 'low voltage', 'lower', 'lumen', 'lumen output',
#        'luminaire', 'made', 'make', 'male', 'male right',
#        'male right angle', 'male straight', 'male straight plug',
#        'mandrel', 'manufacturer', 'mark', 'marked', 'market', 'marking',
#        'marking code', 'material', 'material copper',
#        'material copper alloy', 'mating', 'maximum', 'maximum maximum',
#        'may', 'may used', 'may used read', 'measured', 'measurement',
#        'measuring', 'mechanical', 'mechanical shock', 'medical', 'meet',
#        'melting', 'method', 'method condition', 'method derivation',
#        'method derivation preceding', 'method derived', 'method test',
#        'method test condition', 'metric', 'microphone', 'microwave',
#        'min', 'min min', 'min min min', 'miniature', 'minimum',
#        'minimum maximum', 'minute', 'mode', 'model', 'modular', 'module',
#        'moisture', 'moisture sensitivity', 'moisture sensitivity level',
#        'mount', 'mount fuse', 'mounted', 'mounting', 'multiple', 'must',
#        'na', 'na bulk', 'na bulk na', 'na na', 'na na bulk', 'name',
#        'narrow', 'natural', 'new', 'nickel', 'noise', 'nominal',
#        'nominal cold', 'nominal cold resistance', 'nominal melting',
#        'note', 'note printed', 'note printed copy', 'notice',
#        'notice series', 'notice series fuse', 'number', 'number ampere',
#        'number ampere range', 'number code', 'nylon', 'occupancy', 'ohm',
#        'one', 'open', 'opening', 'opening time', 'operating',
#        'operating temperature', 'operating temperature range',
#        'operation', 'operation product', 'option', 'option specification',
#        'option specification quantity', 'optional', 'orange', 'order',
#        'order number', 'ordered', 'otherwise', 'outdoor', 'outer',
#        'outer conductor', 'outer jacket', 'outer shield', 'output',
#        'output current', 'output voltage', 'overall', 'pack', 'package',
#        'pad', 'page', 'page document', 'page note', 'page note printed',
#        'page specification', 'page specification issue', 'page support',
#        'page support call', 'pair', 'panel', 'parameter', 'part',
#        'part number', 'part stock', 'part system', 'part te',
#        'particular', 'pattern', 'peak', 'peak temperature',
#        'peak temperature time', 'pendant', 'per', 'per reel', 'percent',
#        'performance', 'performance property', 'performance property us',
#        'phone', 'physical', 'pin', 'pitch', 'place', 'plate', 'plated',
#        'plating', 'please', 'please contact', 'please refer', 'plenum',
#        'plug', 'plug hex', 'plug knurl', 'plug knurl solder', 'point',
#        'pole', 'port', 'position', 'power', 'power dissipation',
#        'power supply', 'preceding', 'preceding test',
#        'preceding test method', 'preheat', 'preheat time', 'preparation',
#        'pressure', 'primary', 'printed', 'printed circuit',
#        'printed copy', 'printed copy document', 'prior', 'procedure',
#        'process', 'product', 'product compliance', 'product marking',
#        'product product', 'product selected', 'product selected designed',
#        'profile', 'project', 'propagation', 'property', 'property us',
#        'property us metric', 'protection', 'provide', 'provided',
#        'publication', 'publication information', 'purpose', 'qualified',
#        'quality', 'quantity', 'quantity code', 'quantity quantity',
#        'quantity quantity code', 'radius', 'range', 'rate', 'rated',
#        'rated current', 'rated current rated', 'rated voltage',
#        'rated voltage rated', 'rating', 'rating ampere',
#        'rating interrupting', 'rating interrupting rating',
#        'rating nominal', 'rating nominal cold', 'rating opening',
#        'rating opening time', 'rating voltage', 'rating voltage rating',
#        'ratio', 'reach', 'reach regulation', 'read', 'read complete',
#        'read complete disclaimer', 'reasonable', 'receptacle',
#        'recommendation', 'red', 'reel', 'refer', 'refer page',
#        'reference', 'reference full', 'reference full order', 'reflow',
#        'regulation', 'reliability', 'reliable', 'reliable however',
#        'reliable however independently', 'remote', 'removed',
#        'replacement', 'replacement blade', 'request', 'require',
#        'reserved', 'resistance', 'resistance method',
#        'resistance nominal', 'resistance nominal melting',
#        'resistance soldering', 'resistance soldering heat', 'resistant',
#        'result', 'return', 'rev', 'revision', 'right', 'right angle',
#        'right angle hex', 'room', 'round', 'run', 'safe', 'safety',
#        'sale', 'salt', 'salt spray', 'sample', 'screw', 'sea',
#        'sea level', 'section', 'see', 'see table', 'select', 'selected',
#        'selected designed', 'selected designed may', 'sensitivity',
#        'sensitivity level', 'sensor', 'separately', 'series',
#        'series fuse', 'series series', 'set', 'set forth',
#        'set forth applicable', 'shall', 'shall determined',
#        'shall determined following', 'shall measured', 'shall used',
#        'sheet', 'shield', 'shielded', 'shielding', 'shock',
#        'shock method', 'shock method test', 'short', 'shown',
#        'shown figure', 'side', 'signal', 'silver', 'silver plated',
#        'single', 'size', 'small', 'socket', 'solder', 'solder clamp',
#        'solder crimp', 'solder crimp male', 'soldering', 'soldering heat',
#        'solid', 'solution', 'source', 'space', 'spacing', 'spark', 'spec',
#        'special', 'specific', 'specification', 'specification issue',
#        'specification issue note', 'specification issue page',
#        'specification quantity', 'specification quantity quantity',
#        'specification sheet', 'specify', 'specimen', 'specimen shall',
#        'spray', 'spring', 'spring finger', 'spring finger crimp',
#        'square', 'standard', 'static', 'steel', 'step', 'stock',
#        'storage', 'storage temperature', 'straight', 'straight jack',
#        'straight plug', 'straight plug hex', 'straight plug knurl',
#        'strength', 'stress', 'strip', 'style', 'subject',
#        'subject change', 'subject change without', 'substrate',
#        'suitability', 'suitability test', 'suitability test product',
#        'suitable', 'supply', 'support', 'support call', 'sure', 'surface',
#        'surface mount', 'switch', 'symbol', 'system', 'table', 'tape',
#        'tape reel', 'te', 'te connectivity', 'te connectivity family',
#        'te part', 'technical', 'technical data', 'technology', 'temp',
#        'temperature', 'temperature curve', 'temperature maximum',
#        'temperature min', 'temperature peak', 'temperature range',
#        'temperature temperature', 'temperature time',
#        'temperature time within', 'tensile', 'tensile strength',
#        'terminal', 'terminal strength', 'termination', 'test',
#        'test condition', 'test method', 'test method derivation',
#        'test method derived', 'test product', 'test product selected',
#        'tested', 'tested accordance', 'testing', 'thermal',
#        'thermal shock', 'thermal shock method', 'thickness', 'time',
#        'time current', 'time delay', 'time min', 'time minimum',
#        'time peak', 'time peak temperature', 'time solder',
#        'time temperature', 'time within', 'times', 'times microwave',
#        'tin', 'tin plated', 'tinned', 'tinned copper', 'together',
#        'tolerance', 'tool', 'top', 'total', 'trace', 'transfer', 'trim',
#        'type', 'type bel', 'type bel fuse', 'type number', 'typical',
#        'unbalance', 'uncontrolled', 'uncontrolled copy',
#        'uncontrolled copy te', 'unit', 'universal', 'unless',
#        'unless otherwise', 'us', 'us metric', 'usage', 'use', 'used',
#        'used purpose', 'used read', 'used read complete', 'value',
#        'velocity', 'velocity propagation', 'version', 'vertical',
#        'vibration', 'vibration method', 'view', 'visit', 'volt',
#        'voltage', 'voltage drop', 'voltage rated', 'voltage rating',
#        'voltage rating interrupting', 'voltage withstand', 'wall',
#        'wall thickness', 'warranty', 'wattage', 'wave', 'wave soldering',
#        'way', 'way phone', 'weight', 'wet', 'whether', 'white', 'wide',
#        'width', 'wire', 'wire cable', 'wire size', 'wireless', 'wiring',
#        'within', 'without', 'without notice', 'without notice series',
#        'withstand', 'yes', 'yes yes', 'yes yes yes', 'zone'], dtype=object)

# %%
X_test_vectorized = tfidf.transform(testing_data['pdf_text_sample_cleaned'].values)
y_test = testing_data['target_col'].values

# %%
X_train_vectorized.shape, X_val_vectorized.shape,X_test_vectorized.shape , y_train.shape, y_val.shape, y_test.shape
# Out:
# ((1255, 1000), (140, 1000), (349, 1000), (1255,), (140,), (349,))

# %%
X_test=testing_data['pdf_text_sample_cleaned'].values

# %%
# Check for intersection between train and test sets
train_set = set(X_train)
val_set = set(X_val)
test_set=set(X_test)

overlap = train_set.intersection(val_set)
print(f"Overlap between train and val: {len(overlap)} samples")

overlap = train_set.intersection(test_set)
print(f"Overlap between train and test: {len(overlap)} samples")
# Out:
# Overlap between train and val: 65 samples
# Overlap between train and test: 116 samples

# %% [markdown]
# ### Modelling

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1000)
model.fit(X_train_vectorized, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# #### Evaluation

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

y_pred = model.predict(X_test_vectorized)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#        cable       1.00      1.00      1.00        98
#        fuses       1.00      1.00      1.00       101
#     lighting       1.00      1.00      1.00        66
#       others       1.00      1.00      1.00        84
#
#     accuracy                           1.00       349
#    macro avg       1.00      1.00      1.00       349
# weighted avg       1.00      1.00      1.00       349
#
# [[ 98   0   0   0]
#  [  0 101   0   0]
#  [  0   0  66   0]
#  [  0   0   0  84]]

# %%
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
y_pred_train = model.predict(X_train_vectorized)

print("Accuracy:", accuracy_score(y_train, y_pred_train))
print(classification_report(y_train, y_pred_train))
print(confusion_matrix(y_train, y_pred_train))
# Out:
# Accuracy: 0.998406374501992
#               precision    recall  f1-score   support
#
#        cable       1.00      0.99      1.00       354
#        fuses       1.00      1.00      1.00       363
#     lighting       1.00      1.00      1.00       235
#       others       0.99      1.00      1.00       303
#
#     accuracy                           1.00      1255
#    macro avg       1.00      1.00      1.00      1255
# weighted avg       1.00      1.00      1.00      1255
#
# [[352   0   0   2]
#  [  0 363   0   0]
#  [  0   0 235   0]
#  [  0   0   0 303]]

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100)
model.fit(X_train_vectorized, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

y_pred = model.predict(X_test_vectorized)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#        cable       1.00      1.00      1.00        98
#        fuses       1.00      1.00      1.00       101
#     lighting       1.00      1.00      1.00        66
#       others       1.00      1.00      1.00        84
#
#     accuracy                           1.00       349
#    macro avg       1.00      1.00      1.00       349
# weighted avg       1.00      1.00      1.00       349
#
# [[ 98   0   0   0]
#  [  0 101   0   0]
#  [  0   0  66   0]
#  [  0   0   0  84]]

# %%
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
y_pred_train = model.predict(X_train_vectorized)
print("Accuracy:", accuracy_score(y_train, y_pred_train))
print(classification_report(y_train, y_pred_train))
print(confusion_matrix(y_train, y_pred_train))
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#        cable       1.00      1.00      1.00       354
#        fuses       1.00      1.00      1.00       363
#     lighting       1.00      1.00      1.00       235
#       others       1.00      1.00      1.00       303
#
#     accuracy                           1.00      1255
#    macro avg       1.00      1.00      1.00      1255
# weighted avg       1.00      1.00      1.00      1255
#
# [[354   0   0   0]
#  [  0 363   0   0]
#  [  0   0 235   0]
#  [  0   0   0 303]]
